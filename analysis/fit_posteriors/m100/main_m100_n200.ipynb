# %% [markdown]
# **Description**: Analyze accuracies for $m = 100, n = 200$.
#
# **Estimated runtime**: ~2 hours. (Multi-core isn't working on my machine. Set `cores=4`
# in the `model.fit` call if it works for you.)

# %%
import os
import sys
from typing import Literal

import seaborn as sns

# sys hack to import from grandparent
sys.path.append(os.path.abspath(os.path.join('..', '..')))
import utils
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
num_train: Literal[50, 100] = 100
num_test: Literal[50, 100, 200, 500] = 200

# %%
sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load data

# %%
accuracies_home_dir = os.path.join("..", "..", "accuracies_from_paper")
accuracy_df = utils.load_all_accuracies(
    os.path.join(accuracies_home_dir, f"m{num_train}"), num_test
)  # for plot
num_correct_df = utils.load_all_num_correct(
    os.path.join(accuracies_home_dir, f"m{num_train}"), num_test
)  # for model

# %%
equation = "p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)"
id_vars = ["num_test", "pair", "lm_type", "dataset"]

# %% [markdown]
# # Plot

# %%
utils.violin_plot_multiple_lms(accuracy_df, num_test, num_train)

# %% [markdown]
# # Control

# %%
summary_control, summary_relative_control = utils.eda(
    accuracy_df, treatment="extra", control="base"
)
# Out:
# Overall difference:
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.051792 ┆ 0.010042 │
# └──────────┴──────────┘
# Overall difference (relative):
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.235303 ┆ 0.055126 │
# └──────────┴──────────┘

# %%
summary_control
# Out:
# ┌──────────────────────────────┬─────────┬──────────┐
# │ dataset                      ┆ mean    ┆ se       │
# ╞══════════════════════════════╪═════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.0182  ┆ 0.007115 │
# │ ag_news                      ┆ 0.1875  ┆ 0.008441 │
# │ amazon_counterfactual_en     ┆ 0.111   ┆ 0.025902 │
# │ app_reviews                  ┆ 0.06375 ┆ 0.014664 │
# │ …                            ┆ …       ┆ …        │
# │ trec                         ┆ 0.0744  ┆ 0.009084 │
# │ tweets_hate_speech_detection ┆ 0.0135  ┆ 0.01245  │
# │ yahoo_answers_topics         ┆ 0.0945  ┆ 0.010575 │
# │ yelp_review_full             ┆ 0.02375 ┆ 0.005185 │
# └──────────────────────────────┴─────────┴──────────┘

# %%
summary_relative_control
# Out:
# ┌──────────────────────────────┬──────────┬──────────┐
# │ dataset                      ┆ mean     ┆ se       │
# ╞══════════════════════════════╪══════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.035745 ┆ 0.012906 │
# │ ag_news                      ┆ 0.377502 ┆ 0.021762 │
# │ amazon_counterfactual_en     ┆ 0.458375 ┆ 0.09449  │
# │ app_reviews                  ┆ 0.740728 ┆ 0.111095 │
# │ …                            ┆ …        ┆ …        │
# │ trec                         ┆ 0.38219  ┆ 0.067074 │
# │ tweets_hate_speech_detection ┆ 0.04546  ┆ 0.019826 │
# │ yahoo_answers_topics         ┆ 0.743593 ┆ 0.082037 │
# │ yelp_review_full             ┆ 0.098963 ┆ 0.019722 │
# └──────────────────────────────┴──────────┴──────────┘

# %%
model_control, summary_control, az_summary_control = utils.stat_model(
    num_correct_df,
    treatment="extra",
    control="base",
    equation=equation,
    id_vars=id_vars,
)
# Out:
# /Users/kdubey/Envs/pretrain/lib/python3.11/site-packages/formulae/terms/call.py:108: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_string_dtype(x) or is_categorical_dtype(x) or isinstance(x, CategoricalBox):
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [Intercept, method, lm_type, 1|dataset_sigma, 1|dataset_offset, 1|dataset:pair_sigma, 1|dataset:pair_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 25:24&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 26:34&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 24:35&lt;00:00 Sampling chain 2, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 26:48&lt;00:00 Sampling chain 3, 0 divergences]
#     </div>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 6202 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
#                 mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# method[extra]  0.266  0.005   0.258    0.274        0.0      0.0    4762.0
#
#                ess_tail  r_hat
# method[extra]    2895.0    1.0

# %%
print(model_control)
# Out:
#        Formula: p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)
#         Family: binomial
#           Link: p = logit
#   Observations: 5000
#         Priors:
#     target = p
#         Common-level effects
#             Intercept ~ Normal(mu: 0.0, sigma: 1.0)
#             method ~ Normal(mu: 0.0, sigma: 1.0)
#             lm_type ~ Normal(mu: 0.0, sigma: 5.0)
#
#         Group-level effects
#             1|dataset ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             1|dataset:pair ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# # Treatment

# %%
summary_bias, summary_relative_bias = utils.eda(
    accuracy_df, treatment="test", control="extra"
)
# Out:
# Overall difference:
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.001576 ┆ 0.001397 │
# └──────────┴──────────┘
# Overall difference (relative):
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.026874 ┆ 0.008195 │
# └──────────┴──────────┘

# %%
summary_bias
# Out:
# ┌──────────────────────────────┬─────────┬──────────┐
# │ dataset                      ┆ mean    ┆ se       │
# ╞══════════════════════════════╪═════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.002   ┆ 0.003849 │
# │ ag_news                      ┆ 0.00565 ┆ 0.002884 │
# │ amazon_counterfactual_en     ┆ 0.00615 ┆ 0.012268 │
# │ app_reviews                  ┆ 0.0051  ┆ 0.00856  │
# │ …                            ┆ …       ┆ …        │
# │ trec                         ┆ 0.00025 ┆ 0.009575 │
# │ tweets_hate_speech_detection ┆ 0.0022  ┆ 0.010803 │
# │ yahoo_answers_topics         ┆ -0.0002 ┆ 0.006525 │
# │ yelp_review_full             ┆ -0.0021 ┆ 0.004672 │
# └──────────────────────────────┴─────────┴──────────┘

# %%
summary_relative_bias
# Out:
# ┌──────────────────────────────┬──────────┬──────────┐
# │ dataset                      ┆ mean     ┆ se       │
# ╞══════════════════════════════╪══════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.00517  ┆ 0.0066   │
# │ ag_news                      ┆ 0.009477 ┆ 0.004188 │
# │ amazon_counterfactual_en     ┆ 0.034038 ┆ 0.024227 │
# │ app_reviews                  ┆ 0.055319 ┆ 0.034491 │
# │ …                            ┆ …        ┆ …        │
# │ trec                         ┆ 0.039973 ┆ 0.02561  │
# │ tweets_hate_speech_detection ┆ 0.014504 ┆ 0.016916 │
# │ yahoo_answers_topics         ┆ 0.027456 ┆ 0.023217 │
# │ yelp_review_full             ┆ 0.005059 ┆ 0.015134 │
# └──────────────────────────────┴──────────┴──────────┘

# %%
model_bias, summary_bias, az_summary_bias = utils.stat_model(
    num_correct_df,
    treatment="test",
    control="extra",
    equation=equation,
    id_vars=id_vars,
)
# Out:
# /Users/kdubey/Envs/pretrain/lib/python3.11/site-packages/formulae/terms/call.py:108: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   elif is_string_dtype(x) or is_categorical_dtype(x) or isinstance(x, CategoricalBox):
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [Intercept, method, lm_type, 1|dataset_sigma, 1|dataset_offset, 1|dataset:pair_sigma, 1|dataset:pair_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 24:20&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 54:40&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 19:37&lt;00:00 Sampling chain 2, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 20:58&lt;00:00 Sampling chain 3, 0 divergences]
#     </div>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 7177 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
#                mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# method[test]  0.008  0.005    -0.0    0.017        0.0      0.0    4856.0
#
#               ess_tail  r_hat
# method[test]    3298.0    1.0

# %%
print(model_bias)
# Out:
#        Formula: p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)
#         Family: binomial
#           Link: p = logit
#   Observations: 5000
#         Priors:
#     target = p
#         Common-level effects
#             Intercept ~ Normal(mu: 0.0, sigma: 1.0)
#             method ~ Normal(mu: 0.0, sigma: 1.0)
#             lm_type ~ Normal(mu: 0.0, sigma: 5.0)
#
#         Group-level effects
#             1|dataset ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             1|dataset:pair ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# # Write inference data

# %%
netcdfs = os.path.join("..", "..", "netcdfs", f"m{num_train}")
if not os.path.exists(netcdfs):
    os.mkdir(netcdfs)

# %%
summary_control.to_netcdf(
    filename=os.path.join(netcdfs, f"main_m{num_train}_n{num_test}_control.nc")
)

# %%
summary_bias.to_netcdf(
    filename=os.path.join(netcdfs, f"main_m{num_train}_n{num_test}_treatment.nc")
)
