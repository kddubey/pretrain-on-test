# %% [markdown]
# **Description**: Analyze accuracies for $m = 100, n = 500$.
#
# **Estimated runtime**: ~1 hour. (Multi-core isn't working on my machine. Set `cores=4`
# in the `model.fit` call if it works for you.)

# %%
import os
import sys
from typing import Literal

import seaborn as sns

# sys hack to import from grandparent
sys.path.append(os.path.abspath(os.path.join('..', '..')))
import utils
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
num_train: Literal[50, 100] = 100
num_test: Literal[50, 100, 200, 500] = 500

# %%
sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load data

# %%
accuracies_home_dir = os.path.join("..", "..", "accuracies_from_paper")
accuracy_df = utils.load_all_accuracies(
    os.path.join(accuracies_home_dir, f"m{num_train}"), num_test
)  # for plot
num_correct_df = utils.load_all_num_correct(
    os.path.join(accuracies_home_dir, f"m{num_train}"), num_test
)  # for model

# %%
equation = "p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)"
id_vars = ["num_test", "pair", "lm_type", "dataset"]

# %% [markdown]
# # Plot

# %%
utils.violin_plot_multiple_lms(accuracy_df, num_test, num_train)

# %% [markdown]
# # Control

# %%
summary_control, summary_relative_control = utils.eda(
    accuracy_df, treatment="extra", control="base"
)
# Out:
# Overall difference:
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.050082 ┆ 0.009035 │
# └──────────┴──────────┘
# Overall difference (relative):
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.211253 ┆ 0.046703 │
# └──────────┴──────────┘

# %%
summary_control
# Out:
# ┌──────────────────────────────┬─────────┬──────────┐
# │ dataset                      ┆ mean    ┆ se       │
# ╞══════════════════════════════╪═════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.00015 ┆ 0.008612 │
# │ ag_news                      ┆ 0.12035 ┆ 0.012697 │
# │ amazon_counterfactual_en     ┆ 0.09565 ┆ 0.029372 │
# │ app_reviews                  ┆ 0.11375 ┆ 0.013589 │
# │ blog_authorship_corpus       ┆ 0.0234  ┆ 0.005611 │
# │ …                            ┆ …       ┆ …        │
# │ silicone                     ┆ 0.039   ┆ 0.010794 │
# │ trec                         ┆ 0.09185 ┆ 0.020097 │
# │ tweets_hate_speech_detection ┆ 0.04965 ┆ 0.01783  │
# │ yahoo_answers_topics         ┆ 0.0152  ┆ 0.00569  │
# │ yelp_review_full             ┆ 0.01425 ┆ 0.01034  │
# └──────────────────────────────┴─────────┴──────────┘

# %%
summary_relative_control
# Out:
# ┌──────────────────────────────┬──────────┬──────────┐
# │ dataset                      ┆ mean     ┆ se       │
# ╞══════════════════════════════╪══════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.005007 ┆ 0.01526  │
# │ ag_news                      ┆ 0.241968 ┆ 0.032177 │
# │ amazon_counterfactual_en     ┆ 0.299053 ┆ 0.086785 │
# │ app_reviews                  ┆ 0.875088 ┆ 0.099521 │
# │ blog_authorship_corpus       ┆ 0.049259 ┆ 0.011196 │
# │ …                            ┆ …        ┆ …        │
# │ silicone                     ┆ 0.081492 ┆ 0.020036 │
# │ trec                         ┆ 0.462132 ┆ 0.099285 │
# │ tweets_hate_speech_detection ┆ 0.087765 ┆ 0.029099 │
# │ yahoo_answers_topics         ┆ 0.154844 ┆ 0.052494 │
# │ yelp_review_full             ┆ 0.081729 ┆ 0.045151 │
# └──────────────────────────────┴──────────┴──────────┘

# %%
model_control, summary_control, az_summary_control = utils.stat_model(
    num_correct_df,
    treatment="extra",
    control="base",
    equation=equation,
    id_vars=id_vars,
)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [Intercept, method, lm_type, 1|dataset_sigma, 1|dataset_offset, 1|dataset:pair_sigma, 1|dataset:pair_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 04:12&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 04:07&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 04:21&lt;00:00 Sampling chain 2, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 04:43&lt;00:00 Sampling chain 3, 0 divergences]
#     </div>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1045 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Sampling posterior predictive
#                   mean       sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# method[extra]  0.26298  0.00449   0.25626    0.27035    0.00005  0.00004
#
#                  ess_bulk    ess_tail    r_hat
# method[extra]  8177.04163  3297.33947  0.99983

# %%
print(model_control)
# Out:
#        Formula: p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)
#         Family: binomial
#           Link: p = logit
#   Observations: 2000
#         Priors:
#     target = p
#         Common-level effects
#             Intercept ~ Normal(mu: 0.0, sigma: 1.0)
#             method ~ Normal(mu: 0.0, sigma: 1.0)
#             lm_type ~ Normal(mu: 0.0, sigma: 5.0)
#
#         Group-level effects
#             1|dataset ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             1|dataset:pair ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# # Treatment

# %%
summary_bias, summary_relative_bias = utils.eda(
    accuracy_df, treatment="test", control="extra"
)
# Out:
# Overall difference:
# ┌───────────┬──────────┐
# │ mean      ┆ se       │
# ╞═══════════╪══════════╡
# │ -0.001834 ┆ 0.002254 │
# └───────────┴──────────┘
# Overall difference (relative):
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.021576 ┆ 0.011069 │
# └──────────┴──────────┘

# %%
summary_bias
# Out:
# ┌──────────────────────────────┬──────────┬──────────┐
# │ dataset                      ┆ mean     ┆ se       │
# ╞══════════════════════════════╪══════════╪══════════╡
# │ FRENK-hate-en                ┆ -0.00085 ┆ 0.007218 │
# │ ag_news                      ┆ -0.0003  ┆ 0.00303  │
# │ amazon_counterfactual_en     ┆ 0.0263   ┆ 0.021317 │
# │ app_reviews                  ┆ -0.0036  ┆ 0.013024 │
# │ blog_authorship_corpus       ┆ 0.0028   ┆ 0.002753 │
# │ …                            ┆ …        ┆ …        │
# │ silicone                     ┆ -0.02005 ┆ 0.010684 │
# │ trec                         ┆ 0.01755  ┆ 0.015125 │
# │ tweets_hate_speech_detection ┆ 0.00255  ┆ 0.016002 │
# │ yahoo_answers_topics         ┆ 0.0028   ┆ 0.005162 │
# │ yelp_review_full             ┆ -0.00305 ┆ 0.006843 │
# └──────────────────────────────┴──────────┴──────────┘

# %%
summary_relative_bias
# Out:
# ┌──────────────────────────────┬───────────┬──────────┐
# │ dataset                      ┆ mean      ┆ se       │
# ╞══════════════════════════════╪═══════════╪══════════╡
# │ FRENK-hate-en                ┆ 0.001534  ┆ 0.013578 │
# │ ag_news                      ┆ -0.000011 ┆ 0.003969 │
# │ amazon_counterfactual_en     ┆ 0.080184  ┆ 0.052024 │
# │ app_reviews                  ┆ 0.021547  ┆ 0.044594 │
# │ blog_authorship_corpus       ┆ 0.005176  ┆ 0.005197 │
# │ …                            ┆ …         ┆ …        │
# │ silicone                     ┆ -0.027684 ┆ 0.016884 │
# │ trec                         ┆ 0.084645  ┆ 0.058826 │
# │ tweets_hate_speech_detection ┆ 0.016488  ┆ 0.025341 │
# │ yahoo_answers_topics         ┆ 0.038946  ┆ 0.039188 │
# │ yelp_review_full             ┆ 0.002201  ┆ 0.025257 │
# └──────────────────────────────┴───────────┴──────────┘

# %%
model_bias, summary_bias, az_summary_bias = utils.stat_model(
    num_correct_df,
    treatment="test",
    control="extra",
    equation=equation,
    id_vars=id_vars,
)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (4 chains in 1 job)
# NUTS: [Intercept, method, lm_type, 1|dataset_sigma, 1|dataset_offset, 1|dataset:pair_sigma, 1|dataset:pair_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 03:55&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 04:03&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 04:14&lt;00:00 Sampling chain 2, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 03:52&lt;00:00 Sampling chain 3, 0 divergences]
#     </div>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 967 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Sampling posterior predictive
#                  mean       sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# method[test] -0.00963  0.00459  -0.01673   -0.00211    0.00006  0.00005
#
#                 ess_bulk    ess_tail    r_hat
# method[test]  5703.99264  2777.00956  1.00023

# %%
print(model_bias)
# Out:
#        Formula: p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)
#         Family: binomial
#           Link: p = logit
#   Observations: 2000
#         Priors:
#     target = p
#         Common-level effects
#             Intercept ~ Normal(mu: 0.0, sigma: 1.0)
#             method ~ Normal(mu: 0.0, sigma: 1.0)
#             lm_type ~ Normal(mu: 0.0, sigma: 5.0)
#
#         Group-level effects
#             1|dataset ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             1|dataset:pair ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# # Write inference data

# %%
netcdfs = os.path.join("..", "..", "netcdfs", f"m{num_train}")
if not os.path.exists(netcdfs):
    os.mkdir(netcdfs)

# %%
summary_control.to_netcdf(
    filename=os.path.join(netcdfs, f"main_m{num_train}_n{num_test}_control.nc")
)

# %%
summary_bias.to_netcdf(
    filename=os.path.join(netcdfs, f"main_m{num_train}_n{num_test}_treatment.nc")
)
