# %% [markdown]
# **Description**: Analyze accuracies for $n = 100$.
#
# **Estimated runtime**: ~1.5 hours. (Multi-core isn't working on my machine. Set
# `cores=4` in the `model.fit` call if it works for you.)

# %%
from typing import Literal

import seaborn as sns

import utils
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
num_test: Literal[100, 200, 500] = 100

# %%
sns.set_theme(style="darkgrid")

# %% [markdown]
# # Load data

# %%
accuracies_home_dir = "accuracies_from_paper"
accuracy_df = utils.load_all_accuracies(accuracies_home_dir, num_test)  # for plot
num_correct_df = utils.load_all_num_correct(accuracies_home_dir, num_test)  # for model

# %%
equation = "p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)"
id_vars = ["num_test", "pair", "lm_type", "dataset"]

# %% [markdown]
# # Plot

# %%
utils.violin_plot_multiple_lms(accuracy_df, num_test)

# %% [markdown]
# # Control

# %%
summary_control, summary_relative_control = utils.eda(
    accuracy_df, treatment="extra", control="base"
)
# Out:
# Overall difference:
# ┌─────────┬──────────┐
# │ mean    ┆ se       │
# ╞═════════╪══════════╡
# │ 0.02818 ┆ 0.009338 │
# └─────────┴──────────┘
# Overall difference (relative):
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.206409 ┆ 0.059446 │
# └──────────┴──────────┘

# %%
summary_control
# Out:
# ┌──────────────────────────────┬─────────┬──────────┐
# │ dataset                      ┆ mean    ┆ se       │
# ╞══════════════════════════════╪═════════╪══════════╡
# │ FRENK-hate-en                ┆ -0.0084 ┆ 0.004545 │
# │ ag_news                      ┆ 0.06765 ┆ 0.00506  │
# │ amazon_counterfactual_en     ┆ 0.04205 ┆ 0.011243 │
# │ app_reviews                  ┆ 0.0914  ┆ 0.007939 │
# │ blog_authorship_corpus       ┆ 0.00185 ┆ 0.003925 │
# │ …                            ┆ …       ┆ …        │
# │ silicone                     ┆ -0.0333 ┆ 0.008082 │
# │ trec                         ┆ 0.07275 ┆ 0.009987 │
# │ tweets_hate_speech_detection ┆ 0.0595  ┆ 0.009048 │
# │ yahoo_answers_topics         ┆ 0.02205 ┆ 0.003521 │
# │ yelp_review_full             ┆ 0.0184  ┆ 0.004479 │
# └──────────────────────────────┴─────────┴──────────┘

# %%
summary_relative_control
# Out:
# ┌──────────────────────────────┬───────────┬──────────┐
# │ dataset                      ┆ mean      ┆ se       │
# ╞══════════════════════════════╪═══════════╪══════════╡
# │ FRENK-hate-en                ┆ -0.010157 ┆ 0.008082 │
# │ ag_news                      ┆ 0.135071  ┆ 0.011937 │
# │ amazon_counterfactual_en     ┆ 0.107139  ┆ 0.029498 │
# │ app_reviews                  ┆ 0.746584  ┆ 0.069206 │
# │ blog_authorship_corpus       ┆ 0.009741  ┆ 0.00777  │
# │ …                            ┆ …         ┆ …        │
# │ silicone                     ┆ -0.053935 ┆ 0.015813 │
# │ trec                         ┆ 0.331845  ┆ 0.044494 │
# │ tweets_hate_speech_detection ┆ 0.116221  ┆ 0.016295 │
# │ yahoo_answers_topics         ┆ 0.29912   ┆ 0.042764 │
# │ yelp_review_full             ┆ 0.11177   ┆ 0.023398 │
# └──────────────────────────────┴───────────┴──────────┘

# %%
model_control, summary_control, az_summary_control = utils.stat_model(
    num_correct_df,
    treatment="extra",
    control="base",
    equation=equation,
    id_vars=id_vars,
    draws=250,
    tune=250,
    chains=2,
)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [Intercept, method, lm_type, 1|dataset_sigma, 1|dataset_offset, 1|dataset:pair_sigma, 1|dataset:pair_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 08:46&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 08:43&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 250 tune and 250 draw iterations (500 + 500 draws total) took 1051 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Sampling posterior predictive
#                   mean       sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# method[extra]  0.14874  0.00419   0.14217     0.1553    0.00013  0.00009
#
#                  ess_bulk   ess_tail    r_hat
# method[extra]  1132.29875  368.72818  1.00268

# %%
print(model_control)
# Out:
#        Formula: p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)
#         Family: binomial
#           Link: p = logit
#   Observations: 10000
#         Priors:
#     target = p
#         Common-level effects
#             Intercept ~ Normal(mu: 0.0, sigma: 1.0)
#             method ~ Normal(mu: 0.0, sigma: 1.0)
#             lm_type ~ Normal(mu: 0.0, sigma: 5.0)
#
#         Group-level effects
#             1|dataset ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             1|dataset:pair ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %% [markdown]
# # Treatment

# %%
summary_bias, summary_relative_bias = utils.eda(
    accuracy_df, treatment="test", control="extra"
)
# Out:
# Overall difference:
# ┌───────────┬──────────┐
# │ mean      ┆ se       │
# ╞═══════════╪══════════╡
# │ -0.002468 ┆ 0.001353 │
# └───────────┴──────────┘
# Overall difference (relative):
# ┌──────────┬──────────┐
# │ mean     ┆ se       │
# ╞══════════╪══════════╡
# │ 0.024887 ┆ 0.008304 │
# └──────────┴──────────┘

# %%
summary_bias
# Out:
# ┌──────────────────────────────┬──────────┬──────────┐
# │ dataset                      ┆ mean     ┆ se       │
# ╞══════════════════════════════╪══════════╪══════════╡
# │ FRENK-hate-en                ┆ -0.00715 ┆ 0.0047   │
# │ ag_news                      ┆ 0.00285  ┆ 0.002461 │
# │ amazon_counterfactual_en     ┆ -0.0144  ┆ 0.008194 │
# │ app_reviews                  ┆ -0.0016  ┆ 0.006596 │
# │ blog_authorship_corpus       ┆ 0.0024   ┆ 0.0039   │
# │ …                            ┆ …        ┆ …        │
# │ silicone                     ┆ 0.00505  ┆ 0.004784 │
# │ trec                         ┆ 0.006    ┆ 0.007503 │
# │ tweets_hate_speech_detection ┆ -0.0079  ┆ 0.006511 │
# │ yahoo_answers_topics         ┆ -0.00205 ┆ 0.002871 │
# │ yelp_review_full             ┆ -0.00335 ┆ 0.004904 │
# └──────────────────────────────┴──────────┴──────────┘

# %%
summary_relative_bias
# Out:
# ┌──────────────────────────────┬───────────┬──────────┐
# │ dataset                      ┆ mean      ┆ se       │
# ╞══════════════════════════════╪═══════════╪══════════╡
# │ FRENK-hate-en                ┆ -0.005624 ┆ 0.008324 │
# │ ag_news                      ┆ 0.006575  ┆ 0.003767 │
# │ amazon_counterfactual_en     ┆ -0.010828 ┆ 0.011695 │
# │ app_reviews                  ┆ 0.061801  ┆ 0.028916 │
# │ blog_authorship_corpus       ┆ 0.010179  ┆ 0.007665 │
# │ …                            ┆ …         ┆ …        │
# │ silicone                     ┆ 0.01894   ┆ 0.010355 │
# │ trec                         ┆ 0.05873   ┆ 0.021035 │
# │ tweets_hate_speech_detection ┆ -0.003654 ┆ 0.010754 │
# │ yahoo_answers_topics         ┆ 0.03534   ┆ 0.025183 │
# │ yelp_review_full             ┆ 0.020326  ┆ 0.021685 │
# └──────────────────────────────┴───────────┴──────────┘

# %%
model_bias, summary_bias, az_summary_bias = utils.stat_model(
    num_correct_df,
    treatment="test",
    control="extra",
    equation=equation,
    id_vars=id_vars,
    draws=250,
    tune=250,
    chains=2,
)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (2 chains in 1 job)
# NUTS: [Intercept, method, lm_type, 1|dataset_sigma, 1|dataset_offset, 1|dataset:pair_sigma, 1|dataset:pair_offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 05:28&lt;00:00 Sampling chain 0, 0 divergences]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 05:51&lt;00:00 Sampling chain 1, 0 divergences]
#     </div>
# Sampling 2 chains for 250 tune and 250 draw iterations (500 + 500 draws total) took 681 seconds.
# We recommend running at least 4 chains for robust computation of convergence diagnostics
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Sampling posterior predictive
#                  mean       sd  hdi_5.5%  hdi_94.5%  mcse_mean  mcse_sd  \
# method[test] -0.01307  0.00439   -0.0199   -0.00634    0.00018  0.00013
#
#                ess_bulk   ess_tail    r_hat
# method[test]  610.75502  431.40928  1.00663

# %%
print(model_bias)
# Out:
#        Formula: p(num_correct, num_test) ~ method + lm_type + (1|dataset/pair)
#         Family: binomial
#           Link: p = logit
#   Observations: 10000
#         Priors:
#     target = p
#         Common-level effects
#             Intercept ~ Normal(mu: 0.0, sigma: 1.0)
#             method ~ Normal(mu: 0.0, sigma: 1.0)
#             lm_type ~ Normal(mu: 0.0, sigma: 5.0)
#
#         Group-level effects
#             1|dataset ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
#             1|dataset:pair ~ Normal(mu: 0.0, sigma: HalfNormal(sigma: 1.0))
# ------
# * To see a plot of the priors call the .plot_priors() method.
# * To see a summary or plot of the posterior pass the object returned by .fit() to az.summary() or az.plot_trace()

# %%
summary_control.to_netcdf(filename=f"main_{num_test}_control.nc")
# Out:
# 'main_100_control.nc'

# %%
summary_bias.to_netcdf(filename=f"main_{num_test}_treatment.nc")
# Out:
# 'main_100_treatment.nc'
